# %%
import dask
import dask.dataframe as dd
import dask.array as da
from dask.distributed import Client, LocalCluster
from dask import delayed

import pandas as pd
import numpy as np

from tqdm.notebook import tqdm 

import gensim
from gensim.models.ldamulticore import LdaMulticore as LdaModel
from gensim.corpora import Dictionary, MmCorpus
from gensim.test.utils import datapath

import nltk
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')

import string
import re
import multiprocessing as mp
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /usr4/cs505/bbadnani/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /usr4/cs505/bbadnani/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
client = Client(n_workers=5, threads_per_worker=4)
client
# Out:
# <Client: 'tcp://127.0.0.1:44345' processes=5 threads=20, memory=187.37 GiB>

# %%
# stop loss words 
stop = set(stopwords.words('english'))

# punctuation 
exclude = set(string.punctuation) 

# lemmatization
lemma = WordNetLemmatizer()

# %%
import multiprocessing as mp

mp.cpu_count()
# Out:
# 32

# %%
df = dd.read_csv('../ds-naacp-media-bias/TBG_unique_raw.csv', 
                 usecols = ['position_section','hl1', 'hl2', 'lede', 'body'], 
                 dtype = {'position_section': str,'hl1': object, 
                          'hl2': object, 'lede': str, 'body': str})
df = df.map_partitions(lambda x: x.fillna(''))
df['content'] = df.map_partitions(lambda x: x[['hl1', 'hl2', 'lede', 'body']].agg(' '.join, axis=1))
df = df.drop(columns = ['hl1', 'hl2', 'lede', 'body'])

# %%
#remove urls
re1 = r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))'''
#twitter handles
re2 = '\S*@\S*\s?'
# remove digits
re3 = "\S*\d\S*"
# remove non-ascii characters
re4 = "[^a-zA-Z' ]+"

parser = re.compile("(%s|%s|%s|%s)" % (re1, re2, re3, re4))

def preprocess_text(string_passed):
    return " ".join(y for word in re.sub(parser, ' ', string_passed).split() 
                    if (y := lemma.lemmatize(word.lower())) not in stop and len(y)> 2) # lemmatize and threshold for words > length of 2

def preprocess_text_helper(series):
    return series.map(lambda x: preprocess_text(x))
# Out:
# <ipython-input-6-7f70c599f4a2>:6: DeprecationWarning: Flags not at the start of the expression '((?i)\\b((?:https?://' (truncated)
#   parser = re.compile("(%s|%s|%s|%s)" % (re1, re2, re3, re4))

# %%
test = df.head()

# %%
preprocess_text(test.content[0])
# Out:
# "team air canada's pot issue calgary alberta bruin rely plant based diet nutritional need bruce cassidy want pain i'm bruin coach said using marijuana treat ache ailment come nhl season fact dictate help wednesday canada became largest country world legalize recreational cannabis biggest story nation plastered newspaper social medium body legal nhl city seven canada three california plus boston denver washington pot still federally illegal united state associated press reported nhl nhl player association plan change joint drug testing policy player punished positive marijuana result nfl nba suspend player multiple pot infraction mlb issue fine marijuana banned world anti doping agency among olympic athlete departing canadian trip run calgary wednesday edmonton thursday vancouver saturday ottawa tuesday bruin player given memo nhl educate cannabis legalization safety flame player meeting tuesday teaching point fit duty regardless substance know rule transporting cannabis across country line example player use cannabis medicine legally canada cannot bring legally united state visitors' dressing room scotiabank saddledome topic passed around morning skate cannabis long stigmatized drug bruin player asked directly used medically recreationally thought reflected changing attitude society sport know enough said cassidy i'm open minded term someone could convince better speak millenn ials seem feel way pot advocate tout benefit cannabis compound offer pain relief without making user feel high associated press story week edmonton oiler superstar connor mcdavid said player would stupid look drug's ability treat ache pain long nhl season comment caught attention boston defenseman brandon carlo watched home state legalize i've never much interest concept see partaking using said carlo colorado spring guy start research i'll start pick brain forward jake debrusk said seen positive result friend none nhl player used pain management time country make legal think got benefit said debrusk noted use among cancer patient guess conversation start we'll find scituate mass native ryan donato said interested looking medical cannabis know lot guy said line there's benefit i'm sure league realize want player best shape make sure they're healing right way brad marchand said he'll continue use whatever team doctor prescribe affect one way said marchand halifax nova scotia legal legal think going change whole lot around league cassidy ottawa said smoke agree cigar cigarette pot like taste smell said considers book type guy like many canadian he's eager see country's decision play doe work we'll trend setter said we'll look like idiot time tell debrusk edmonton offered message fellow canadian guess legal stay safe drive high anything like said that's opinion respectful whatever want wednesday debrusk's birthday bruin began run three road game four night much position celebrate occasion news day joking mood obviously circulating twittersphere said hey guess legal i'm canadian that's way heavy hit charlie mcavoy knocked johnny gaudreau game late hit third left mcavoy called interference finished calgary wing hit behind net calgary coach bill peter said gaudreau pulled ice nhl's concussion spotter playing power play mcavoy likely disciplined league even though late hit spotlight another slightly built standout vancouver rookie elia pettersson body slammed florida's mike matheson last saturday defenseman received two game suspension gaudreau reached mark game david pastrnak hit century mark follow matt porter twitter"

# %%
lemma.lemmatize('words') # Use it once first, to "unlazify" wordnet.
preprocess = df.content.map_partitions(preprocess_text_helper, 
                                         meta=pd.Series([], dtype=str, name='content'))

#run this cell to unlazify wordnet

# %%
from dask.distributed import progress

result = preprocess.persist()
progress(result)
# Out:
# VBox()

# %%
result = preprocess.to_frame().to_parquet(
    "pre-processed-persist", engine="pyarrow"
)

#write it back to the disk in preprcoessed format

# %%
df = dd.read_parquet(
    "pre-processed-persist",
    engine="pyarrow")

#read the preprocessed data back in

# %%
df.content.partitions[0].compute()

#visualize the data
# Out:
# 0        Team air Canada's pot issue calgary alberta br...
# 1        Treasury worker charged leak washington senior...
# 2        Funny Women luncheon raise record Rosie's Plac...
# 3        Turkish official say audio reveals torture ist...
# 4        Journal pull stem cell researcher's paper Conc...
#                                ...
# 13335    CORRECTION correction editor's error photo che...
# 13336    Police defend probe teacher police standing be...
# 13337    Forbes sidestep tradition unorthodox campaign ...
# 13338    CORRECTION correction reporting error story we...
# 13339    Managers must decide today manager corp offere...
# Name: content, Length: 13340, dtype: object

# %%
df.shape[0].compute()

#get the amount of articles
# Out:
# 1621013

# %%
"""dictionary = Dictionary(line[1].content.split() for line in tqdm(df.iterrows(), total = 1621013))"""

#uncomment these the first time you run it
# Out:
#   0%|          | 0/1621013 [00:00<?, ?it/s]

# %%
"""dictionary.save('dictionary')"""
#uncomment these the first time you run it

# %%
dictionary = Dictionary.load('dictionary')

# %%
len(dictionary)
# Out:
# 2000715

# %%
dictionary.filter_extremes(no_below=10)
#dont keep any words that occur less than 10 times
#look up gensim's filter_extremes documentation - default parameter keeps 100000 in the dictionary

# %%
len(dictionary)
# Out:
# 100000

# %%
words = set(k for k, _ in dictionary.token2id.items())
#words is a set of all the words in the dictionary

# %%
words
# Out:
# {'outlasvegasing',
#  'blodry',
#  'wwwseifaorgmonthlyshowshtml',
#  'shigenobu',
#  'cycleoriented',
#  'icemasters',
#  'atmeac',
#  'wwwbostoncommcas',
#  'gospelfriendly',
#  'plazacom',
#  'liwill',
#  'demartine',
#  'chapelgate',
#  'torrancenorth',
#  'duparc',
#  'skepticisim',
#  'mamat',
#  'englishteacher',
#  'loungefrequent',
#  'wwwfloridacanoecom',
#  'kral',
#  'kjernisted',
#  'brownpapered',
#  'greenechandos',
#  'mocean',
#  'contemporaryskrtskrt',
#  'madrugada',
#  'mchoice',
#  'terra',
#  'headrillaz',
#  'incredibletheyll',
#  'zelinda',
#  'dsheriff',
#  'gormley',
#  'insurancecompanies',
#  'freebiesquasibribes',
#  'democratwas',
#  'shieldwhat',
#  'bluescolored',
#  'airchamber',
#  'immigrationthe',
#  'baabridgeport',
#  'gudiwada',
#  'winmaking',
#  'pubrecordscom',
#  'kavrakos',
#  'thinnestskinned',
#  'wwwallasiafoodexpocom',
#  'doharriet',
#  'squarcia',
#  'brooksson',
#  'bonacca',
#  'oftenbut',
#  'middelesex',
#  'luijkenstraat',
#  'railwalk',
#  'wwwperiodcraftsmencom',
#  'nwide',
#  'hnic',
#  'mcishirleys',
#  'impending',
#  'povertyplagued',
#  'toldyouso',
#  'laurendesigned',
#  'pmshriners',
#  'departmentglobe',
#  'scalzos',
#  'phoenixcartoonist',
#  'eksos',
#  'rekdesign',
#  'confusingly',
#  'photochantal',
#  'organicfarming',
#  'raceblindness',
#  'wwwarrtincorg',
#  'viedaycom',
#  'demandsthe',
#  'concertssome',
#  'jarvt',
#  'bieryloof',
#  'bonsteels',
#  'whisperjet',
#  'vashkar',
#  'chidinma',
#  'exgenuity',
#  'govetts',
#  'foxkey',
#  'wineapplei',
#  'highcalorie',
#  'moreausr',
#  'maisrequested',
#  'happenus',
#  'orderto',
#  'qaisari',
#  'laabes',
#  'connells',
#  'huthaifa',
#  'handcaught',
#  'schlesigner',
#  'phowie',
#  'talksstyle',
#  'wwwsaffrondocom',
#  'widebacked',
#  'fwoed',
#  'directorsnew',
#  'conflictofethics',
#  'mergermarket',
#  'blackmetalshoegaze',
#  'buffalosyracuse',
#  'chopan',
#  'neimatu',
#  'grillgreen',
#  'dedaso',
#  'obscurer',
#  'collinsexecutive',
#  'baltake',
#  'kzone',
#  'allour',
#  'meleo',
#  'wifeys',
#  'mancusco',
#  'firsty',
#  'commonssunday',
#  'thedevelopment',
#  'camachostewart',
#  'supercozy',
#  'bainbashing',
#  'naiah',
#  'posturing',
#  'womanrelationship',
#  'polledout',
#  'screengrabbing',
#  'focusedzombie',
#  'kamskyblatny',
#  'dahmeresque',
#  'groceryfilled',
#  'operationsincludes',
#  'lotteryrock',
#  'thenleague',
#  'yemenmilitants',
#  'telex',
#  'kerastick',
#  'getawaycar',
#  'vegasonviagra',
#  'diamondnaga',
#  'toquilla',
#  'soetjipto',
#  'bridgeviews',
#  'wwwdirereadercom',
#  'arizonapac',
#  'seerrious',
#  'kottairdis',
#  'seasearch',
#  'manyang',
#  'bangladeshbased',
#  'quartertodate',
#  'truehoop',
#  'washingtondallasdallasphoenixphoenixat',
#  'ownen',
#  'edgaar',
#  'callssidebarthe',
#  'lowcosthighupside',
#  'medialounge',
#  'anantaras',
#  'tonsillar',
#  'petmad',
#  'tuman',
#  'makotos',
#  'frumiousbandersnatch',
#  'rofekamps',
#  'positivelooking',
#  'leonte',
#  'vardonwest',
#  'stran',
#  'disproved',
#  'dannatt',
#  'frenchcontrolled',
#  'kellerbier',
#  'roannaise',
#  'pastvietnam',
#  'benyoub',
#  'fujianese',
#  'socialwelfare',
#  'registerrefers',
#  'paraszczak',
#  'inperiod',
#  'kidman',
#  'valveq',
#  'sartretolee',
#  'visitingbesides',
#  'tjaden',
#  'colleenconnor',
#  'naominaomi',
#  'breitbarthguidi',
#  'finessedriven',
#  'recalculating',
#  'mingay',
#  'fenerjian',
#  'lohrke',
#  'ltpgtmrs',
#  'walstatter',
#  'chanting',
#  'kadisons',
#  'nintendowants',
#  'ndongs',
#  'championshipsrl',
#  'pubco',
#  'illbuilt',
#  'actukally',
#  'beadcatching',
#  'eeeoowwws',
#  'perejil',
#  'stingly',
#  'wwwhistoricsaranaclake',
#  'comettant',
#  'cornandblackbean',
#  'baldwinkevin',
#  'shinyfloored',
#  'genzymeasked',
#  'temescu',
#  'jagr',
#  'irs',
#  'texana',
#  'earlysigning',
#  'ethacrynic',
#  'toupence',
#  'buurial',
#  'hililihilo',
#  'garbageand',
#  'bingsoo',
#  'showwonder',
#  'honigmann',
#  'grapefruitlitchilime',
#  'foxfetish',
#  'skanty',
#  'habittracking',
#  'butouk',
#  'thoroughlyq',
#  'bigga',
#  'concertwhitneys',
#  'womanlady',
#  'fiveandfive',
#  'latermegan',
#  'pullin',
#  'mwramanaged',
#  'backcenturies',
#  'jackknifing',
#  'shtetele',
#  'wwwroadtocollegecom',
#  'origami',
#  'energyformerly',
#  'olivierkozlowskichairman',
#  'keolishave',
#  'successhandling',
#  'wwwvailcomskiandsnowboardschoolwomeninskiingaspx',
#  'sfcwife',
#  'develleroy',
#  'rappana',
#  'gholamhosein',
#  'smcbainsailsincorg',
#  'pleasureloving',
#  'panagio',
#  'leonidnik',
#  'kanshil',
#  'singlechannel',
#  'soontobeavailable',
#  'marieceleste',
#  'rostephenson',
#  'mandiants',
#  'resigntunis',
#  'residsences',
#  'deepseating',
#  'fleetmodernization',
#  'faniss',
#  'languagesjapan',
#  'concreteandtin',
#  'tophey',
#  'guyscable',
#  'refill',
#  'gamedeolis',
#  'trimmedup',
#  'huaian',
#  'rummidge',
#  'derissaint',
#  'wilamai',
#  'bartkowksi',
#  'sorbetiere',
#  'positiveaerosmith',
#  'grozina',
#  'pagewho',
#  'quecha',
#  'walpolearea',
#  'aulino',
#  'templebrooklinecom',
#  'phiyang',
#  'cherrygerman',
#  'byrnesalvarado',
#  'sangworn',
#  'eyedropper',
#  'gershanoff',
#  'lifecoaching',
#  'ceolarry',
#  'pregregorian',
#  'threebelt',
#  'grouporgdon',
#  'norefusal',
#  'combinatin',
#  'ricenorton',
#  'suchacka',
#  'editorialized',
#  'higheropportunity',
#  'gaymale',
#  'etymologizer',
#  'gorgonzolastuffed',
#  'ubeidi',
#  'morethantwoyear',
#  'channing',
#  'wwwrobertkleingallery',
#  'thisisthewayitshouldbe',
#  'invote',
#  'fahs',
#  'rikala',
#  'pfadfinderei',
#  'santeran',
#  'goldbergted',
#  'cutlerled',
#  'glendalee',
#  'lessthanfullstrength',
#  'preceptions',
#  'lactobacillus',
#  'patazetovic',
#  'byelections',
#  'basketballgoings',
#  'vitaminddeficient',
#  'vischniac',
#  'corridor',
#  'tinnyvoiced',
#  'kenins',
#  'seinfeld',
#  'csturgeon',
#  'carpettacking',
#  'falconeborsellino',
#  'turneb',
#  'salesanother',
#  'alqawsi',
#  'ariaspinnock',
#  'locationary',
#  'alyami',
#  'swerviest',
#  'resembled',
#  'fosterjames',
#  'saleros',
#  'wwwbigchickenbarncom',
#  'dikener',
#  'bisnett',
#  'champtions',
#  'saela',
#  'backgroundsgeary',
#  'hison',
#  'coozman',
#  'wisealecky',
#  'whitesnappy',
#  'covidienmanagers',
#  'loveyourneighbor',
#  'trasks',
#  'scaliashe',
#  'tooties',
#  'bateadorers',
#  'jhooks',
#  'wwwmerrimacknhgov',
#  'alaskafinch',
#  'wwwfayschoolorgweatherweatherhtml',
#  'rossolimo',
#  'nbcsb',
#  'bergelin',
#  'tamaqua',
#  'kiddfueled',
#  'agofinally',
#  'questdocumentarycom',
#  'altruistically',
#  'ruhelos',
#  'creamcarpeted',
#  'debendox',
#  'falperra',
#  'foreheadhairline',
#  'onetwothree',
#  'massachusettsstyle',
#  'mapleblack',
#  'facebookwith',
#  'bogle',
#  'eygalieres',
#  'saidmetroregion',
#  'fielddocument',
#  'samoncik',
#  'dancingsinging',
#  'krua',
#  'fedorasporting',
#  'ternational',
#  'forumsdelphiforumscomactonmapoliticsstart',
#  'donkova',
#  'throatsong',
#  'wwwtanabarutourscoza',
#  'stallingshas',
#  'donilar',
#  'nonweatherized',
#  'felipo',
#  'obartuck',
#  'lefthandeddecision',
#  'teacuptinkly',
#  'nyzsthe',
#  'displaywriter',
#  'unoppressed',
#  'mennie',
#  'sexyteenager',
#  'velicky',
#  'keyspans',
#  'lawfor',
#  'raytheonfor',
#  'bullsnew',
#  'cadavertainment',
#  'fabre',
#  'indevusdrug',
#  'flibanen',
#  'nervously',
#  'saltuve',
#  'ovechkincrosbymalkin',
#  'talkingbragging',
#  'aljets',
#  'dobrokego',
#  'flexprofessionals',
#  'litronic',
#  'millionare',
#  'chojnicki',
#  'squiddy',
#  'xiangyi',
#  'kuriharcuch',
#  'finfet',
#  'vympelkom',
#  'lacno',
#  'youngmonet',
#  'nordgaard',
#  'wojtowiczvosloo',
#  'whatforward',
#  'murraymilfordalzheimers',
#  'bigfeeling',
#  'mannysidebarhere',
#  'mortgageback',
#  'hyperspace',
#  'winshippen',
#  'amtraksymbolizes',
#  'incidentsits',
#  'rabotin',
#  'centermadeleft',
#  'halbritters',
#  'hartfordpitney',
#  'thetoughone',
#  'alexanderscott',
#  'moustks',
#  'thenlawyer',
#  'saintstitans',
#  'junipersmoked',
#  'editorpublisher',
#  'kealler',
#  'yuya',
#  'arrowflinging',
#  'regularmisses',
#  'technogeek',
#  'wwwbgscombiogen',
#  'onehomer',
#  'justunemployed',
#  'shenandoa',
#  'chimberg',
#  'walkietalkies',
#  'radiatorshaped',
#  'audanoise',
#  'jupiterwell',
#  'verasteguis',
#  'veraz',
#  'oneroomwide',
#  'plankton',
#  'idarose',
#  'munetz',
#  'nationalversuslocal',
#  'deborah',
#  'tetua',
#  'adsorbs',
#  'everprogressing',
#  'vitolinshadorjan',
#  'duringlow',
#  'bitterstarmer',
#  'abbadabba',
#  'davaris',
#  'bumpylooking',
#  'auru',
#  'vantineown',
#  'undermanaged',
#  'ammsnbccycling',
#  'tvrated',
#  'leguna',
#  'fogengendered',
#  'ownercook',
#  'seebyte',
#  'wwwsfgatecom',
#  'kaplanof',
#  'unleashing',
#  'uars',
#  'passreliant',
#  'trophied',
#  'catskillarea',
#  'wrkodo',
#  'hurld',
#  'odongi',
#  'carrasquilosuarez',
#  'nearsuicidal',
#  'stotz',
#  'twothree',
#  'duranttoboston',
#  'annuallyits',
#  'kfiance',
#  'scassellati',
#  'nocommercials',
#  'preleukemia',
#  'yongil',
#  'thismissed',
#  'midmass',
#  'macleanmembers',
#  'permanentefacilities',
#  'wwwloonorg',
#  'whitelisted',
#  'killmain',
#  'finernibbed',
#  'protectionjenna',
#  'radicondoli',
#  'aboukhalils',
#  'musicianturnedchef',
#  'yesharkins',
#  'alshamir',
#  'toughnessin',
#  'universalthey',
#  'rearflattering',
#  'meetgreet',
#  'wwwnorthbakerycom',
#  'lajohnson',
#  'miled',
#  'santanderand',
#  'gidpholliday',
#  'tishs',
#  'chauth',
#  'megapharma',
#  'equilars',
#  'krasowskis',
#  'ehrs',
#  'raffishlygarbed',
#  'chesterfieldstyle',
#  'valaya',
#  'drumstrings',
#  'mcallesters',
#  'borregaard',
#  'twelveohonesecond',
#  'fakeout',
#  'hammertap',
#  'sterz',
#  'kornicks',
#  'summersled',
#  'seatbelt',
#  'olympicsfigures',
#  'chagallinspired',
#  'ryanryan',
#  'delbou',
#  'changeannual',
#  'dignifiedsounding',
#  'forfedex',
#  'kmcdonald',
#  'fingernailchewing',
#  'zerka',
#  'posely',
#  'graftonstreet',
#  'raramuri',
#  'reherasal',
#  'pinkbordered',
#  'prcwa',
#  'heffern',
#  'auchard',
#  'actresspoetteacher',
#  'workshigh',
#  'togetherunless',
#  'oftdominated',
#  'fightsaround',
#  'berrycurrant',
#  'moledotted',
#  'wwwfranciscanguest',
#  'breakfastwhat',
#  'aktarian',
#  'karapakula',
#  'squill',
#  'augusty',
#  'paintedscenery',
#  'feehanharvard',
#  'butdoes',
#  'overcarpentered',
#  'twofree',
#  'blachmanbenitez',
#  'crossrates',
#  'sindarov',
#  'baseballrich',
#  'indofizz',
#  'copturnedinvestigator',
#  'piccola',
#  'wmcemercyhurstedu',
#  'kamakurabostoncom',
#  'seesun',
#  'ageewalker',
#  'retailservice',
#  'antiprotozoan',
#  'balladcumtrainwreck',
#  'mpri',
#  'saidfield',
#  'stationoftheyear',
#  'torval',
#  'rer',
#  'nonfoodobsessed',
#  'teratology',
#  'daeman',
#  'finbury',
#  'oldpeoplenotactingtheirage',
#  'otherwisestandard',
#  'gasolinedrenched',
#  'yuewhite',
#  'hourswellbridge',
#  'collinsfaunce',
#  'artistmusicianantique',
#  'ileocecal',
#  'unnixonian',
#  'hotenoughorg',
#  'creatologist',
#  'selfamputation',
#  'cantorcooke',
#  'bostonmetrowest',
#  'wwwchanseggrollsandjazzcom',
#  'schwent',
#  'addedseabrook',
#  'sojournerspun',
#  'headturningly',
#  'kalininsky',
#  'loures',
#  'mackaycoghill',
#  'erebiapepito',
#  'taurel',
#  'sergeyeva',
#  'culturebullycom',
#  'doklahoma',
#  'definedpension',
#  'zherebenkov',
#  'thedisecomexhibitan',
#  'pantsless',
#  'smithkin',
#  'daira',
#  'cookiescom',
#  'rousac',
#  'millerbellhorn',
#  'bridgewateryunits',
#  'violining',
#  'watertownltstronggt',
#  'dorieclarkcom',
#  'bostonglobecombusiness',
#  'kickmyself',
#  'armgesturing',
#  'lehmanartcenterorg',
#  'gamecast',
#  'vians',
#  'mayorovaivanova',
#  'smykowski',
#  'jingdont',
#  'capisco',
#  'touristbait',
#  'wellvalued',
#  'casinobound',
#  'intrudedupon',
#  'checkdowns',
#  'oooohh',
#  'fergusoneric',
#  'hurndall',
#  'wwwplanecrashinfocom',
#  'oftenstaged',
#  'cclamps',
#  'constrictor',
#  'wwwkeytourscom',
#  'goker',
#  'tartanplaid',
#  'bowdlerizer',
#  'sumpin',
#  'torchinsky',
#  'overrules',
#  'gurgitating',
#  'bigsaddle',
#  'cruisethis',
#  'shruggedoff',
#  'essbaums',
#  'lilianett',
#  'lyfting',
#  'fecalsplattered',
#  'wwwmosorg',
#  'hijacksthe',
#  'grabbiness',
#  'westerbeke',
#  'drugdispensing',
#  'nutballs',
#  'usq',
#  'pensionsetting',
#  'wwwbiddingforgoodcomemerson',
#  'vouli',
#  'demarche',
#  'boxbound',
#  'chasser',
#  'douche',
#  'peshlers',
#  'kohokhlovich',
#  'fordman',
#  'nuedexta',
#  'surprisemay',
#  'beewee',
#  'betterball',
#  'ased',
#  'fsforo',
#  'rokevious',
#  'breookline',
#  'budgert',
#  'recalled',
#  'nightcarr',
#  'debtpooling',
#  'teodecki',
#  'dollarpercalorie',
#  'arrarga',
#  'sidak',
#  'pity',
#  'mouit',
#  'arlingtonlexington',
#  'reblochonstyle',
#  'grainily',
#  'ljim',
#  'threeagency',
#  'undercovertype',
#  'ladegard',
#  'prodniester',
#  'hymoff',
#  'sandlice',
#  'sarbaums',
#  'namegathering',
#  'loudmartin',
#  'greensboro',
#  'lannis',
#  'garrottpeltier',
#  'wwwharleydavidsoncom',
#  'quinoaandlentilbased',
#  'foodbooks',
#  'followrev',
#  'aladeens',
#  'kramp',
#  'percocetwhich',
#  'playerlines',
#  'amazonwe',
#  'seasonminor',
#  'taxesimmigration',
#  'truthsoul',
#  'alarsan',
#  'highwaybuilding',
#  'naderwhose',
#  'psychsoftpc',
#  'bacteriatainted',
#  'emls',
#  'stoppeddear',
#  'jobbentley',
#  'chargeerror',
#  'aprowl',
#  'phoneinternetcable',
#  'fungiforrester',
#  'bickneses',
#  'geithnerobama',
#  'scansource',
#  'gerwicks',
#  'khui',
#  'winssidebarat',
#  'sevencyclescom',
#  'mascotthe',
#  'urlinges',
#  'widelyloathed',
#  'fluteharp',
#  'committo',
#  'zenefits',
#  'yoni',
#  'aherns',
#  'wwwadirectorycombirding',
#  'websterzinn',
#  'thistleslike',
#  'saylesinvestment',
#  'spaceriding',
#  'frankenshoes',
#  'teacupful',
#  'antireligiousat',
#  'windivision',
#  'dcastro',
#  'yeliseyevsky',
#  'narking',
#  'strangleri',
#  'localguy',
#  'hearmecom',
#  'priftis',
#  'travelamerica',
#  'avolcano',
#  'cornila',
#  'takingexsox',
#  'selfhelpless',
#  'humanturnedhalf',
#  'scalpburning',
#  'reto',
#  'familythemed',
#  'charliecharliechallenge',
#  'selfbrushing',
#  'lazerbeak',
#  'cleon',
#  'sluggo',
#  'httpwwwjeepunpavedcom',
#  'riveracollazo',
#  'linglis',
#  'honfleur',
#  'wallgrennorwoodbudget',
#  'savageaus',
#  'gothpunks',
#  'trinastarliteloungecomamesbury',
#  'sfisdaz',
#  'authorhumorist',
#  'umenosan',
#  'ubeckett',
#  'compromiseaverse',
#  'dawa',
#  'livongrosman',
#  'athleteloyola',
#  'mpgarnold',
#  'claymations',
#  'antennaeyes',
#  'odelle',
#  'wwwcapecodcafepizzacom',
#  'whatgot',
#  'revew',
#  'descalzada',
#  'candidatesfrom',
#  'bribeloving',
#  'electrometabograph',
#  'ubps',
#  'jozy',
#  'chinarussia',
#  'raincoatslick',
#  'thisabbrookline',
#  'weods',
#  'mingmine',
#  'schoenauer',
#  'musicobsessed',
#  'riverk',
#  'esukpa',
#  'greating',
#  'capbreton',
#  'cooperaton',
#  'pzizz',
#  'habitatdestroying',
#  'theatlanta',
#  'fingerinelectricsocket',
#  'benaglia',
#  'tazachocolates',
#  'harfman',
#  'familyincrisis',
#  'bargebike',
#  'cibum',
#  'hedmark',
#  'freeredline',
#  'beerfeltz',
#  'pattinsonwillem',
#  'sciencebymail',
#  'boomspurred',
#  'deser',
#  'skalkas',
#  'nyg',
#  'eitherrob',
#  'fullybald',
#  'jarbato',
#  'livebutweakened',
#  'mesli',
#  'wimberlys',
#  'mercuria',
#  'puaena',
#  'sickhigh',
#  'dorcesterbased',
#  'usukraine',
#  'secularminded',
#  'joccole',
#  'aymanns',
#  'appendicitis',
#  'interpretingesoblogspotcom',
#  'rerhs',
#  'lowellgood',
#  'rewardsteering',
#  'featurettestill',
#  'unneccesarily',
#  'modernpastrycom',
#  'psychoktherapy',
#  'murch',
#  'impactcole',
#  'thdre',
#  'defillo',
#  'cutgone',
#  'horrorfantasies',
#  'sity',
#  'elkin',
#  'quarterbillionaires',
#  'ittough',
#  'baselworld',
#  'overfly',
#  'coloradomedical',
#  'concordcarlislehad',
#  'screamsaturated',
#  'transideological',
#  'kimmerling',
#  'edmus',
#  'toenailpolish',
#  'recitalworthy',
#  'pasig',
#  'wwwbnrcorgtrailsandmapsmahannacobble',
#  'demiranda',
#  'pareand',
#  'macyof',
#  'sobkowicz',
#  'pianosized',
#  'lineuphodge',
#  'cornponeandhardcider',
#  'sharesvery',
#  'verizonproperty',
#  'hudsondoris',
#  'bwame',
#  'websitewwwpunk',
#  'musicfasharvardeducalendarhtml',
#  'handicapadjusted',
#  'gwilly',
#  'crimeepic',
#  'eba',
#  'boundaryconscious',
#  'tightends',
#  'caffeinecravers',
#  'avrin',
#  'wwwphyzgigorg',
#  'elmakarim',
#  'trumpification',
#  'whatdown',
#  'acri',
#  'seleka',
#  'masscba',
#  'outfelder',
#  'autofraudo',
#  'christofellis',
#  'stand',
#  'horth',
#  'finfrock',
#  'guidomike',
#  'exadventure',
#  'spiritwingsbethelcom',
#  'biohaven',
#  'kearney',
#  'npaul',
#  'farmeraround',
#  'freshsqueeze',
#  'fbiinformant',
#  'neroseems',
#  'devolving',
#  'squatcher',
#  'demob',
#  'organaires',
#  'lobate',
#  'pignon',
#  'playersstars',
#  'petrobrascontracts',
#  'thankyouforapplying',
#  'pasvik',
#  'burmatibet',
#  'powerpreserving',
#  'swietens',
#  'ranted',
#  'textdependent',
#  'cranstonri',
#  'bikeonly',
#  'steeves',
#  'steroidjacked',
#  'transexual',
#  'vetcall',
#  'squirmworthy',
#  'newsprint',
#  'kautai',
#  'sagoffs',
#  'whiley',
#  'auditthinking',
#  'amlohas',
#  'middeearth',
#  'bloodpumping',
#  ...}

# %%
dictionary.doc2bow('eject')
#look into this later
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-525a69f6dba0> in <module>
# ----> 1 dictionary.doc2bow('eject')
#
# ~/.local/lib/python3.8/site-packages/gensim/corpora/dictionary.py in doc2bow(self, document, allow_update, return_missing)
#     237         """
#     238         if isinstance(document, str):
# --> 239             raise TypeError("doc2bow expects an array of unicode tokens on input, not a single string")
#     240
#     241         # Construct (word, frequency) mapping.
#
# TypeError: doc2bow expects an array of unicode tokens on input, not a single string

# %%
class Corpus:
    def __init__(self, n_gram = 'Unigram'):
        self.df = df = dd.read_parquet("pre-processed-persist",engine="pyarrow")
        self.words = set(k for k, _ in dictionary.token2id.items())
        
    def __iter__(self):
        for line in self.df.iterrows(): 
            # assume there's one document per line, tokens separated by whitespace
            yield dictionary.doc2bow(word for word in line[1].content.split() if word in self.words) #like return but only one at a time

# %%
corpus = Corpus()

# %%
MmCorpus.serialize('corpus.mm', tqdm(corpus, total = 1621013) )
#serialize the corpus to disk in specified format so that LDA can read it one at a time
#can take a minute or two to run
# Out:
#   0%|          | 0/1621013 [00:00<?, ?it/s]

# %%
corpus = MmCorpus(datapath('corpus.mm'))

# %%
lda_model = LdaModel(corpus = tqdm(corpus, total = 1621013), id2word=dictionary, 
                     num_topics=30, eval_every=5, per_word_topics=True, chunksize = 100, passes=10, 
                     workers=4)
# Out:
#   0%|          | 0/1621013 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-11342e339db0> in <module>
# ----> 1 lda_model = LdaModel(corpus = tqdm(corpus, total = 1621013), id2word=dictionary,
#       2                      num_topics=30, eval_every=5, per_word_topics=True, chunksize = 100, passes=10,
#       3                      workers=7)
#
# ~/.local/lib/python3.8/site-packages/gensim/models/ldamulticore.py in __init__(self, corpus, num_topics, id2word, workers, chunksize, passes, batch, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, random_state, minimum_probability, minimum_phi_value, per_word_topics, dtype)
#     184             raise NotImplementedError("auto-tuning alpha not implemented in LdaMulticore; use plain LdaModel.")
#     185
# --> 186         super(LdaMulticore, self).__init__(
#     187             corpus=corpus, num_topics=num_topics,
#     188             id2word=id2word, chunksize=chunksize, passes=passes, alpha=alpha, eta=eta,
#
# ~/.local/lib/python3.8/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     518             use_numpy = self.dispatcher is not None
#     519             start = time.time()
# --> 520             self.update(corpus, chunks_as_numpy=use_numpy)
#     521             self.add_lifecycle_event(
#     522                 "created",
#
# ~/.local/lib/python3.8/site-packages/gensim/models/ldamulticore.py in update(self, corpus, chunks_as_numpy)
#     309                         process_result_queue()
#     310
# --> 311                 process_result_queue()
#     312             # endfor single corpus pass
#     313
#
# ~/.local/lib/python3.8/site-packages/gensim/models/ldamulticore.py in process_result_queue(force)
#     273             merged_new = False
#     274             while not result_queue.empty():
# --> 275                 other.merge(result_queue.get())
#     276                 queue_size[0] -= 1
#     277                 merged_new = True
#
# /share/pkg.7/python3/3.8.10/install/lib/python3.8/multiprocessing/queues.py in get(self, block, timeout)
#      95         if block and timeout is None:
#      96             with self._rlock:
# ---> 97                 res = self._recv_bytes()
#      98             self._sem.release()
#      99         else:
#
# /share/pkg.7/python3/3.8.10/install/lib/python3.8/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# /share/pkg.7/python3/3.8.10/install/lib/python3.8/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     419         if maxsize is not None and size > maxsize:
#     420             return None
# --> 421         return self._recv(size)
#     422
#     423     def _poll(self, timeout):
#
# /share/pkg.7/python3/3.8.10/install/lib/python3.8/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
lda_model

# %%
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic))
    print("\n")
# Out:
# Topic: 0
# Words: 0.000*"report" + 0.000*"treasury" + 0.000*"edward" + 0.000*"suspicious" + 0.000*"story" + 0.000*"leak" + 0.000*"agent" + 0.000*"news" + 0.000*"charged" + 0.000*"activity"
#
#
# Topic: 1
# Words: 0.000*"report" + 0.000*"treasury" + 0.000*"financial" + 0.000*"activity" + 0.000*"court" + 0.000*"suspicious" + 0.000*"charged" + 0.000*"edward" + 0.000*"story" + 0.000*"senior"
#
#
# Topic: 2
# Words: 0.000*"treasury" + 0.000*"senior" + 0.000*"report" + 0.000*"court" + 0.000*"activity" + 0.000*"suspicious" + 0.000*"financial" + 0.000*"story" + 0.000*"edward" + 0.000*"charged"
#
#
# Topic: 3
# Words: 0.000*"report" + 0.000*"treasury" + 0.000*"court" + 0.000*"edward" + 0.000*"senior" + 0.000*"financial" + 0.000*"charged" + 0.000*"trump" + 0.000*"suspicious" + 0.000*"agent"
#
#
# Topic: 4
# Words: 0.000*"treasury" + 0.000*"report" + 0.000*"edward" + 0.000*"story" + 0.000*"financial" + 0.000*"charged" + 0.000*"suspicious" + 0.000*"senior" + 0.000*"filed" + 0.000*"court"
#
#
# Topic: 5
# Words: 0.000*"said" + 0.000*"wednesday" + 0.000*"new" + 0.000*"body" + 0.000*"say" + 0.000*"1" + 0.000*"first" + 0.000*"work" + 0.000*"government" + 0.000*"2"
#
#
# Topic: 6
# Words: 0.000*"charged" + 0.000*"suspicious" + 0.000*"senior" + 0.000*"activity" + 0.000*"treasury" + 0.000*"report" + 0.000*"financial" + 0.000*"court" + 0.000*"edward" + 0.000*"news"

# %%
# these cells are just badman attempting shit

id2word = Dictionary()
id2word.filter_extremes(no_below=15, no_above=0.4, keep_n=80000)

# %%
lda_model = LdaModel(id2word=id2word, 
                     num_topics=7, alpha='auto', eval_every=5, per_word_topics=True, chunksize = 100, passes=10)

# %%
test = dask.compute(*result.partitions[1])
